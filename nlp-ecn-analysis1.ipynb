# %% [markdown]
# # Word Count and sentiment analysis of ECN (NLP)
#
#
# ### description, special instruction and title
#
#
# ### works repetition high requency image
#
# ### repeated words count
#
# ### sentiment analysis
#
#
#
# ## Recommendation

# %%
# Required Imports
import pandas as pd
import nltk
#import keras

import numpy as np
import re

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# from nltk.tokenize import RegexpTokenizer
#
# tokenizer = RegexpTokenizer(r'\w+')
#
# data['tokens'] = data['text'].apply(tokenizer.tokenize)
# data[['text', 'tokens']].head()

# %%
#creating dataframe 
df1 = pd.read_csv('nlp-data.csv')

# %%
#readong first 5 rows of "NL I09"
df1.head()
# Out:
#   RELEASE_DATE  CLASSIFICATION KEYED_NAME CREATED_ON  \
# 0      55:31.0             NaN   ECN-7787    05:29.3
# 1      13:47.0             NaN    EC07143    05:16.0
# 2      03:51.0             NaN  EC06768BW    17:15.1
# 3      16:48.0             NaN   ECN-7789    01:49.9
# 4      14:45.0             NaN  EC06619AX    35:06.5
#
#                                  ID                       OWNED_BY_ID  \
# 0  0003BBE18CC94AB0A0A8E33741D72A75  9F071C97417346E0942860F4B6E20CAB
# 1  00193BDEC74B4B349B62F4CF06E825FA  3A102D05B09A4CFD943A0F88DCC4462C
# 2  0079ABE913D14523A0E0F2ED24C90C0D  7D003C82BBDE4C20BD9BC1EA06CA224F
# 3  008AEA179613463F8A4215221F7B19F3  9F071C97417346E0942860F4B6E20CAB
# 4  00AFECD7757040CFA2C014345124BFDD  358ED79676F346A09FA6AB7B0FE9A600
#
#                       CREATED_BY_ID                    MODIFIED_BY_ID  \
# 0  5E8146986A6A434D875FCDC59F9EF7CE  6D7971B909B942E8842722FCB1B41FDE
# 1  66A7F9F13758481A8365B11EA4C965D9  F44BA6A37A5048A48CA0AAB9881A987F
# 2  335C0F17DA6442ADA38D9C6DFFAD63A6  D05D760E41304C55B1304A2936BD7AD8
# 3  5E8146986A6A434D875FCDC59F9EF7CE  9357DD6C3FBA45DFA2A7DDE7DD31FF31
# 4  C0CA2B7147EA442AAA851AF487B98ED4  D05D760E41304C55B1304A2936BD7AD8
#
#    MANAGED_BY_ID MODIFIED_ON  ...  \
# 0            NaN     56:31.8  ...
# 1            NaN     02:39.7  ...
# 2            NaN     03:51.5  ...
# 3            NaN     18:03.5  ...
# 4            NaN     14:45.5  ...
#
#                                 SPECIAL_INSTRUCTIONS  \
# 0         Per feedback from ICL and Project engineer
# 1  Display units are duplicated using the same co...
# 2  HPWH Project has the PSO & Pilot Run this mont...
# 3  after reviewing plenum assembly and burner fla...
# 4  AS49064 was released at EC06619AC, but BOM was...
#
#                                              TITLE      STATE  \
# 0                   Refractory changes 1MM & 1.5MM  Completed
# 1                          Gen V HPWH PSS Revision  Completed
# 2                                        EC06768BW  Completed
# 3              3MM & 4MM Refractories minor update  Completed
# 4  Super High Efficiency Gas Tankless Water Heater  Completed
#
#    RH_ESTIMATED_IMPLEMENTATION_DATE  RH_RELEASE_TYPE  RH_PRODUCT_GROUP  \
# 0                               NaN      Project/NPI       XVERS W/KOR
# 1                               NaN      Maintenance              HPWH
# 2                               NaN      Project/NPI              HPWH
# 3                               NaN      Project/NPI       XVERS W/KOR
# 4                               NaN      Project/NPI      Tankless Gas
#
#    RH_OWNER_DEPARTMENT  RH_CHANGE_CATEGORY  RH_CREATED_BY_DIVISION  \
# 0            R & D Eng      Drawing Change                  Raypak
# 1            R & D Eng      Drawing Change                      WH
# 2            R & D Eng      Drawing Change                      WH
# 3            R & D Eng      Drawing Change                  Raypak
# 4            R & D Eng          BOM Change                      WH
#
#   RH_PRODUCTION_DESIGNATION
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 40 columns]

# %%
# looking at null values and data types of each column for "NL I09"
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2342 entries, 0 to 2341
# Data columns (total 40 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   RELEASE_DATE                      1925 non-null   object
#  1   CLASSIFICATION                    0 non-null      float64
#  2   KEYED_NAME                        2342 non-null   object
#  3   CREATED_ON                        2342 non-null   object
#  4   ID                                2342 non-null   object
#  5   OWNED_BY_ID                       2342 non-null   object
#  6   CREATED_BY_ID                     2342 non-null   object
#  7   MODIFIED_BY_ID                    2342 non-null   object
#  8   MANAGED_BY_ID                     0 non-null      float64
#  9   MODIFIED_ON                       2342 non-null   object
#  10  CURRENT_STATE                     2342 non-null   object
#  11  LOCKED_BY_ID                      68 non-null     object
#  12  MAJOR_REV                         2342 non-null   object
#  13  IS_CURRENT                        2342 non-null   int64
#  14  NOT_LOCKABLE                      2342 non-null   int64
#  15  IS_RELEASED                       2342 non-null   int64
#  16  MINOR_REV                         0 non-null      float64
#  17  CSS                               0 non-null      float64
#  18  GENERATION                        2342 non-null   int64
#  19  PERMISSION_ID                     2342 non-null   object
#  20  NEW_VERSION                       2342 non-null   int64
#  21  CONFIG_ID                         2342 non-null   object
#  22  TEAM_ID                           2342 non-null   object
#  23  BASIS                             0 non-null      float64
#  24  DESCRIPTION                       2342 non-null   object
#  25  CUSTOMER_APPROVAL                 2342 non-null   int64
#  26  EFFECTIVITY_DATE                  882 non-null    object
#  27  ITEM_NUMBER                       2342 non-null   object
#  28  IMPLEMENTATION_PLAN               0 non-null      float64
#  29  PRIORITY                          0 non-null      float64
#  30  SPECIAL_INSTRUCTIONS              2342 non-null   object
#  31  TITLE                             2342 non-null   object
#  32  STATE                             2342 non-null   object
#  33  RH_ESTIMATED_IMPLEMENTATION_DATE  0 non-null      float64
#  34  RH_RELEASE_TYPE                   2342 non-null   object
#  35  RH_PRODUCT_GROUP                  2342 non-null   object
#  36  RH_OWNER_DEPARTMENT               2282 non-null   object
#  37  RH_CHANGE_CATEGORY                2289 non-null   object
#  38  RH_CREATED_BY_DIVISION            2342 non-null   object
#  39  RH_PRODUCTION_DESIGNATION         202 non-null    object
# dtypes: float64(8), int64(6), object(26)
# memory usage: 732.0+ KB

# %%
df1.columns
# Out:
# Index(['RELEASE_DATE', 'CLASSIFICATION', 'KEYED_NAME', 'CREATED_ON', 'ID',
#        'OWNED_BY_ID', 'CREATED_BY_ID', 'MODIFIED_BY_ID', 'MANAGED_BY_ID',
#        'MODIFIED_ON', 'CURRENT_STATE', 'LOCKED_BY_ID', 'MAJOR_REV',
#        'IS_CURRENT', 'NOT_LOCKABLE', 'IS_RELEASED', 'MINOR_REV', 'CSS',
#        'GENERATION', 'PERMISSION_ID', 'NEW_VERSION', 'CONFIG_ID', 'TEAM_ID',
#        'BASIS', 'DESCRIPTION', 'CUSTOMER_APPROVAL', 'EFFECTIVITY_DATE',
#        'ITEM_NUMBER', 'IMPLEMENTATION_PLAN', 'PRIORITY',
#        'SPECIAL_INSTRUCTIONS', 'TITLE', 'STATE',
#        'RH_ESTIMATED_IMPLEMENTATION_DATE', 'RH_RELEASE_TYPE',
#        'RH_PRODUCT_GROUP', 'RH_OWNER_DEPARTMENT', 'RH_CHANGE_CATEGORY',
#        'RH_CREATED_BY_DIVISION', 'RH_PRODUCTION_DESIGNATION'],
#       dtype='object')

# %%
# based on which columns we have to filter

# Division only "water heater"
#

# %%
# filter for each item as a separet df file
df1['RH_CREATED_BY_DIVISION'].unique()
# Out:
# array(['Raypak', 'WH', 'AC', 'Intergas', 'HTPG'], dtype=object)

# %%
# this can be a good point to find an exact person and info related to that
# df1['OWNED_BY_ID'].unique()

# %%
df1['RH_CHANGE_CATEGORY'].unique()
# Out:
# array(['Drawing Change', 'BOM Change', 'Product Improvement',
#        'New End Item(s)', 'Cost Reduction', 'Regulation',
#        'Customer Request', 'Quality Improvement', 'Literature Change',
#        nan, 'Safety Issue'], dtype=object)

# %%
df1['RH_PRODUCT_GROUP'].unique()
# Out:
# array(['XVERS W/KOR', 'HPWH', 'Tankless Gas', 'Residential Electric',
#        'Multiple Groups', 'Commerial Package Units', 'Hi_Delta',
#        'Commercial Splits', 'XPAK FT', 'Residential Gas', 'HPPH',
#        'Commercial Gas', 'AVIA', 'Many', 'Residential Gas Furnaces',
#        'XVERS L', 'IFIRE', 'Commercial', 'Residential Package Units',
#        'Residential Splits', 'XFIIRE', 'MVB', 'XTherm',
#        'International Commercial', 'Gas Fired Water Heaters',
#        'Commercial Electric', 'International Residential',
#        'Residential Air Handlers', 'Pool', 'S_22', 'XVERS', 'Coils',
#        'Multiple group', 'Tankless Electric', '106_506 Pool', 'MVB RAPL',
#        'Protege', 'Commercial IPL', 'HTPG Product group', 'SERVICE',
#        'Crosswind', 'Daytona HE', 'E3T', 'Raytherm', 'Controls', 'Solar',
#        'X_94', 'Gas Fired Boilers', 'VERSA SIMULATOR'], dtype=object)

# %%
df1['RH_OWNER_DEPARTMENT'].unique()
# Out:
# array(['R & D Eng', 'Manufacturing', 'Quality', 'Product Management', nan,
#        'Procurement', 'Tech Support/Apps', 'Prod Mgmt'], dtype=object)

# %%
df11 = df1[['TITLE', 'DESCRIPTION', 'SPECIAL_INSTRUCTIONS', 'RH_RELEASE_TYPE',
       'RH_PRODUCT_GROUP', 'RH_OWNER_DEPARTMENT', 'RH_CHANGE_CATEGORY',
       'RH_CREATED_BY_DIVISION']]

# %%
df11.head()
# Out:
#                                              TITLE  \
# 0                   Refractory changes 1MM & 1.5MM
# 1                          Gen V HPWH PSS Revision
# 2                                        EC06768BW
# 3              3MM & 4MM Refractories minor update
# 4  Super High Efficiency Gas Tankless Water Heater
#
#                                          DESCRIPTION  \
# 0  Adding to tolerance note "UNLESS OTHERWISE SPE...
# 1  Design Services:\nRevise drawings based on the...
# 2  Update drawings per attached markups. These ch...
# 3  moving 2 center hole and patch locations to fi...
# 4  Structure Bills of Material for the AS49064 pa...
#
#                                 SPECIAL_INSTRUCTIONS RH_RELEASE_TYPE  \
# 0         Per feedback from ICL and Project engineer     Project/NPI
# 1  Display units are duplicated using the same co...     Maintenance
# 2  HPWH Project has the PSO & Pilot Run this mont...     Project/NPI
# 3  after reviewing plenum assembly and burner fla...     Project/NPI
# 4  AS49064 was released at EC06619AC, but BOM was...     Project/NPI
#
#   RH_PRODUCT_GROUP RH_OWNER_DEPARTMENT RH_CHANGE_CATEGORY  \
# 0      XVERS W/KOR           R & D Eng     Drawing Change
# 1             HPWH           R & D Eng     Drawing Change
# 2             HPWH           R & D Eng     Drawing Change
# 3      XVERS W/KOR           R & D Eng     Drawing Change
# 4     Tankless Gas           R & D Eng         BOM Change
#
#   RH_CREATED_BY_DIVISION
# 0                 Raypak
# 1                     WH
# 2                     WH
# 3                 Raypak
# 4                     WH

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2342 entries, 0 to 2341
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TITLE                   2342 non-null   object
#  1   DESCRIPTION             2342 non-null   object
#  2   SPECIAL_INSTRUCTIONS    2342 non-null   object
#  3   RH_RELEASE_TYPE         2342 non-null   object
#  4   RH_PRODUCT_GROUP        2342 non-null   object
#  5   RH_OWNER_DEPARTMENT     2282 non-null   object
#  6   RH_CHANGE_CATEGORY      2289 non-null   object
#  7   RH_CREATED_BY_DIVISION  2342 non-null   object
# dtypes: object(8)
# memory usage: 146.5+ KB

# %%
df12 = df11[df11['RH_CREATED_BY_DIVISION'] == 'WH']

# %%
df12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1366 entries, 1 to 2341
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TITLE                   1366 non-null   object
#  1   DESCRIPTION             1366 non-null   object
#  2   SPECIAL_INSTRUCTIONS    1366 non-null   object
#  3   RH_RELEASE_TYPE         1366 non-null   object
#  4   RH_PRODUCT_GROUP        1366 non-null   object
#  5   RH_OWNER_DEPARTMENT     1339 non-null   object
#  6   RH_CHANGE_CATEGORY      1343 non-null   object
#  7   RH_CREATED_BY_DIVISION  1366 non-null   object
# dtypes: object(8)
# memory usage: 96.0+ KB

# %%
df12['RH_CREATED_BY_DIVISION'].unique()
# Out:
# array(['WH'], dtype=object)

# %%
df12['RH_CHANGE_CATEGORY'].unique()
# Out:
# array(['Drawing Change', 'BOM Change', 'Product Improvement',
#        'New End Item(s)', 'Regulation', 'Customer Request', nan,
#        'Literature Change', 'Cost Reduction', 'Quality Improvement',
#        'Safety Issue'], dtype=object)

# %%
df12['RH_OWNER_DEPARTMENT'].unique()
# Out:
# array(['R & D Eng', 'Manufacturing', 'Quality', nan, 'Product Management',
#        'Prod Mgmt', 'Procurement'], dtype=object)

# %%
df12['RH_PRODUCT_GROUP'].unique()
# Out:
# array(['HPWH', 'Tankless Gas', 'Residential Electric', 'Multiple Groups',
#        'Residential Gas', 'Commercial Gas', 'Commercial Electric',
#        'Multiple group', 'Tankless Electric', 'Solar'], dtype=object)

# %%
df12['RH_RELEASE_TYPE'].unique()
# Out:
# array(['Maintenance', 'Project/NPI', 'CIP Maintenance'], dtype=object)

# %%
#creating dataframe df1 of "NL I09"
df2 =  df12[['TITLE', 'DESCRIPTION', 'SPECIAL_INSTRUCTIONS']]

# %%
df2.head()
# Out:
#                                               TITLE  \
# 1                           Gen V HPWH PSS Revision
# 2                                         EC06768BW
# 4   Super High Efficiency Gas Tankless Water Heater
# 5                                         EC06973A
# 6  Super High Efficiency Gas Tankless Water Heaters
#
#                                          DESCRIPTION  \
# 1  Design Services:\nRevise drawings based on the...
# 2  Update drawings per attached markups. These ch...
# 4  Structure Bills of Material for the AS49064 pa...
# 5  need to relocate LABEL - DO NOT RETURN as per ...
# 6                  Update AX5214 drawing per markup.
#
#                                 SPECIAL_INSTRUCTIONS
# 1  Display units are duplicated using the same co...
# 2  HPWH Project has the PSO & Pilot Run this mont...
# 4  AS49064 was released at EC06619AC, but BOM was...
# 5  1) DO NOT RETURN LABEL placement need to be th...
# 6                    Found some errors on a drawing.

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1366 entries, 1 to 2341
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TITLE                 1366 non-null   object
#  1   DESCRIPTION           1366 non-null   object
#  2   SPECIAL_INSTRUCTIONS  1366 non-null   object
# dtypes: object(3)
# memory usage: 42.7+ KB

# %%
df2['TITLE'].value_counts()
# Out:
# Tankless Sustainable Packaging                                 12
# SASO ENERGY LABELS                                              9
# Super High Efficiency Gas Tankless Water Heater                 8
# Add Supplement Sheet (AP18234) information to U&C Manuals.      8
# Hybrid Electric Gen 5 for Canada                                7
#                                                                ..
# EC07018E: Element Designs due to MEA Field Failures             1
# Universal Induced Draft (GD Series) to be discontinued          1
# Dragon - EC06677EB Top Pan Assembly Update                      1
# Email Test 4                                                    1
# FLUE PIPE INSULATION AP13626 FROM ROUND TO HEXAGONAL SHAPE      1
# Name: TITLE, Length: 1177, dtype: int64

# %%
df2['TITLE'].unique()
# Out:
# array(['Gen V HPWH PSS Revision', 'EC06768BW',
#        'Super High Efficiency Gas Tankless Water Heater', ...,
#        'NIAGARA - UPDATE OUTDOOR KIT',
#        'Pinnacle Ph4 Residential Pilot Drawing Update',
#        'Super High Efficiency Gas Tankless Water Heater PDR'],
#       dtype=object)

# %%
df2['DESCRIPTION'].value_counts()
# Out:
# 1. Drawing/model changes according to marked drawings.\n2. Release the drawings included in this ADR.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          7
# Update all literature according to the standard ANSI Z21.10.1-2017 • CSA 4.1-2017\nSustaining Design Engineering Services\n1. Make changes to drawings according markup attached.\n\nTechnical Manual Coordinator\n1. Make changes to manuals according to the markup attached.                                                                                                                                                                                                                                                                                                                                6
# Create certification drawings for the components used in Eagle 1 and Eagle tankless products.  Please refer to the attached spreadsheet for the full list of drawings needed.  The steps for drawing creation are:\n1) Review the spreadsheet to find the Part Number of the new certification drawing in Column B\n2) Locate the 3D model and reference drawing in Teams -> Certification Drawings -> General -> Files -> [Step.1] 3D data & Drawing from Paloma\n3) Create the drawing based upon the 3D model using the reference drawing as a template to guide what details and information to include    5
# Design Services:\nRevise Drawings according to the attached marked drawing.  \n\nManual Specialist:\nRevise Manuals according to the attached marked Manuals.                                                                                                                                                                                                                                                                                                                                                                                                                                                  5
# Update drawings per attached markups                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           4
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ..
# ECN Cancelled\n\nI need preliminary drawing for below part numbers \n- AP22199 - Suction line \n- AP22200 - discharge line \n- AP22201 - suction line to valve \n- AP22203 - discharge line to tank \n- AP22204 - discharge to tank                                                                                                                                                                                                                                                                                                                                                                            1
# 1. Update drawing AP21839 per the attached mark-up\n2. Create top pad drawing AP22193 based on the mark-up and supplier files                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# 1. Create 4 new jacket flats followed by the formed jackets. Then create drawings for these new parts.\n2. Markup is attached with part numbers for each new part shown in the markup.                                                                                                                                                                                                                                                                                                                                                                                                                         1
# please update BOM for 701479 end item as per attached BI sheet. \nAlso attached a sample BOM that it should reflect in oracle. \nplease do check with sample BOM attached for accuracy in Oracle after loading in oracle.                                                                                                                                                                                                                                                                                                                                                                                      1
# Create wire harness drawing AP22387 per attached markup                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# Name: DESCRIPTION, Length: 1254, dtype: int64

# %%
df2['DESCRIPTION'].unique()
# Out:
# array(['Design Services:\nRevise drawings based on the attached markups.\n\nEngineering Services:\nSet end items 700466 & 700465 to LEVEL 6.',
#        'Update drawings per attached markups. These changes needs to be complete next week at 02/13/20',
#        'Structure Bills of Material for the AS49064 part numbers.', ...,
#        'Update AP21064 with drawing changes.  This will be a minor revision.  Extension "A" is currently used in production, but these changes only make the drawing consistent with what is actually being supplied.  Extension "B" is not used in production yet.  This is for EC06634.  This needs to be released by Feb 11, 2021.',
#        'Design Services:\nRevise AP18408 as per markups attached',
#        'Update/Create BOM per the attached BI report'], dtype=object)

# %%
df2['SPECIAL_INSTRUCTIONS'].value_counts()
# Out:
# Washington State is requiring all electrics sold in their state to be DR ready by Jan 1, 2022                                                                                                                                                                             19
# All Rheem residential gas water heaters manuals need to be updated to the latest CSA/ANSI Z21.10.1:19 * CSA 4.1:19 Standard.\n\nNOTE:  EC MUST BE EFFECTIVE BEFORE MAY 1st, 2021                                                                                          10
# Customer request                                                                                                                                                                                                                                                           8
# PR Migrated from Windchill                                                                                                                                                                                                                                                 7
# EB3/Pre-Pilot                                                                                                                                                                                                                                                              7
#                                                                                                                                                                                                                                                                           ..
# This is part of the field correction that will improve quality.                                                                                                                                                                                                            1
# Updating some structures, quantities, and descriptions of parts.                                                                                                                                                                                                           1
# approve drawing.                                                                                                                                                                                                                                                           1
# Revise drawings.                                                                                                                                                                                                                                                           1
# 1. Need to add NMFC package and box certificate stamps on the drawing, current carton tubes already have the stamps on it (see picture attached), only drawing change.\n2. Need to revise "K" dimension to reflect real dimension on product, see print card attached.     1
# Name: SPECIAL_INSTRUCTIONS, Length: 1180, dtype: int64

# %%
df2['SPECIAL_INSTRUCTIONS'].unique()
# Out:
# array(['Display units are duplicated using the same configuration as 700463.\nMinor correction to the marketing model needed in order to match Oracle/AHRI on PSS-HB40G5, PSS-HB50G5, PSS-HB65G5 & PSS-HB80G5',
#        'HPWH Project has the PSO & Pilot Run this month. These changes needs to be complete next week at 02/13/20',
#        'AS49064 was released at EC06619AC, but BOM was not structured at the EC. AS49064A through M should have BOM. ',
#        ..., 'Drawing change only.',
#        'TOD supplier is shutdown, as an alternative to keep production running Resideo Thermistor will be used. \n\nSecond Release to revise resideo thermistor. Further EC will revise assy. burner drawings, and PSS sheet C to add the Alternate burner assy. in order for the plant to be able swap burner assy. as needed.',
#        'BOM errors have found, and BOM of one end item has not been created yet. \nThis change request to update/create BOM.'],
#       dtype=object)

# %%
df2.isnull().sum()
# Out:
# TITLE                   0
# DESCRIPTION             0
# SPECIAL_INSTRUCTIONS    0
# dtype: int64

# %%
# bar chart to see missing visual in df_data
plt.figure(figsize = (8,8))

df2.isnull().sum().plot(kind = 'barh')
plt.title('Number of Missing Values by Column', size = 25)
plt.xlabel('Count', size = 25);

# %%
notes = df2['SPECIAL_INSTRUCTIONS']
df_notes = ' '.join(notes.to_list())

# %%
#!pip install wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
word_cloud = WordCloud(max_font_size=40).generate(df_notes)

# %%
plt.figure(figsize=(14,8))
plt.imshow(word_cloud, interpolation='bilinear')
plt.show()

# %% [markdown]
# ## Word Count method
#
# ### in addition to above image of high frequency word, we can count words as below

# %% [markdown]
# Tokenization is the process of breaking the text into smaller pieces called Tokens. It can be performed at sentences(sentence tokenization) or word level(word tokenization).
#
# Tokenizers divide strings into lists of substrings.

# %% [markdown]
# If we wanted a computer to interpret these sentences, I might count up how many times I see each word. The computer will treat words like "running," "ran," and "runs" differently... but they mean very similar things (in this context)!
#
# Lemmatizing and stemming are two forms of shortening words so we can combine similar forms of the same word.
#
# When we "lemmatize" data, we take words and attempt to return their lemma, or the base/dictionary form of a word.

# %% [markdown]
# ### Tokenizing and Stemming Data

# %%
def tokenize_lemmatize(text1_col):
    # Instantiate tokenizer
    tokenizer = RegexpTokenizer(r'[A-z]+')
    
    # Tokenize text
    tokens = [tokenizer.tokenize(text1.lower()) for text1 in text1_col]
    
    # Instantiate lemmatizer
    lemmatizer = WordNetLemmatizer()
    
    tokens_lem = []
    # lemmatize words
    for words in tokens:
        lem_list = [lemmatizer.lemmatize(i) for i in words]
        lem_post = ''
        for word in lem_list:
            lem_post += (word+' ')
        tokens_lem.append(lem_post.strip())
    
    return (tokens_lem)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\muhammad.tahir.ctr\AppData\Roaming\nltk_data.
# [nltk_data]     ..
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer

# %%
lem_token_list = tokenize_lemmatize(df2['SPECIAL_INSTRUCTIONS'])

# %%
lem_token_list[2]
# Out:
# 'a wa released at ec ac but bom wa not structured at the ec a a through m should have bom'

# %%
# Instantiate lemmatizer.
lemmatizer = WordNetLemmatizer()

# %%
# Lemmatize the word "computers."
lemmatizer.lemmatize("computers")
# Out:
# 'computer'

# %%
lemmatizer.lemmatize("computer")
# Out:
# 'computer'

# %%
lemmatizer.lemmatize("computation")
# Out:
# 'computation'

# %%
lemmatizer.lemmatize("computationally")
# Out:
# 'computationally'

# %% [markdown]
# ### Stemming Data
#
# When we "stem" data, we take words and attempt to return a base form of the word. It tends to be cruder than using lemmatization. There's a method developed by Porter in 1980 that explains the algorithm used below.

# %%
# Tokenizing and Lemmatizing Data
from nltk.stem.porter import PorterStemmer

# Instantiate PorterStemmer.
p_stemmer = PorterStemmer()

# %%
# Stem the word "computer."
p_stemmer.stem("computer")
# Out:
# 'comput'

# %%
# Stem the word "computation."
p_stemmer.stem("computation")
# Out:
# 'comput'

# %%
# Stem the word "computationally."
p_stemmer.stem("computationally")
# Out:
# 'comput'

# %%
from sklearn.feature_extraction.text import CountVectorizer
import regex as re
from sklearn.feature_extraction import text

# %%
cvec = CountVectorizer()
lem_features = cvec.fit_transform(lem_token_list)

# %%
lem_features
# Out:
# <1366x2115 sparse matrix of type '<class 'numpy.int64'>'
# 	with 20104 stored elements in Compressed Sparse Row format>

# %%
vocab = cvec.get_feature_names()
print(vocab)
# Out:
# ['_b', 'ab', 'able', 'about', 'above', 'ac', 'acceptable', 'accepted', 'access', 'accessory', 'accidentally', 'accommodate', 'accompanying', 'accomplish', 'according', 'accordinto', 'accumulation', 'accurate', 'acknowledge', 'across', 'action', 'activates', 'active', 'activity', 'actual', 'actually', 'adapt', 'adapter', 'adaptor', 'add', 'added', 'adding', 'addition', 'additional', 'address', 'adhesive', 'adjust', 'adjusted', 'adjustment', 'adoption', 'adr', 'advantage', 'advertised', 'ae', 'aesthetic', 'af', 'affect', 'affected', 'affecting', 'after', 'aftermarket', 'ag', 'again', 'against', 'agency', 'ago', 'agreed', 'ahri', 'ai', 'aid', 'aim', 'air', 'ak', 'alarm', 'alfredo', 'align', 'alignment', 'all', 'allow', 'allowable', 'allowed', 'allows', 'already', 'also', 'alternate', 'alternative', 'altitude', 'am', 'amazon', 'ambient', 'amendment', 'america', 'amount', 'an', 'analysis', 'analyze', 'ance', 'and', 'angela', 'angle', 'angular', 'annual', 'anode', 'another', 'ansi', 'antenna', 'anthony', 'any', 'anymore', 'anything', 'ao', 'ap', 'apart', 'apcom', 'app', 'appear', 'appearance', 'applicable', 'application', 'applied', 'applies', 'apply', 'approach', 'appropriate', 'approval', 'approve', 'approved', 'approx', 'arabia', 'arabian', 'are', 'area', 'aren', 'arise', 'armando', 'around', 'arrow', 'art', 'artwork', 'asap', 'ask', 'asked', 'asme', 'assembled', 'assembly', 'assign', 'assigned', 'assignment', 'assist', 'associated', 'assurance', 'assure', 'assy', 'asv', 'at', 'ati', 'atmospheric', 'attached', 'attaching', 'attachment', 'attempt', 'attic', 'au', 'audit', 'auditing', 'august', 'authorization', 'auto', 'automatic', 'availability', 'available', 'average', 'avoid', 'avoided', 'awareness', 'awg', 'ax', 'az', 'aztek', 'b_obs', 'back', 'background', 'backlight', 'backwards', 'badge', 'baffle', 'bag', 'balon', 'banding', 'barcode', 'base', 'based', 'baseline', 'basic', 'battery', 'be', 'became', 'because', 'become', 'been', 'before', 'begin', 'being', 'below', 'benefit', 'better', 'between', 'bg', 'bi', 'bilingual', 'bill', 'binding', 'bird', 'bj', 'black', 'blacked', 'blank', 'blanket', 'block', 'blower', 'bm', 'board', 'boards_', 'bob', 'body', 'bolt', 'bom', 'boms', 'boot', 'both', 'bottom', 'box', 'boxed', 'boxing', 'bq', 'br', 'bracket', 'bradford', 'brand', 'branded', 'branding', 'brass', 'bravo', 'breakdown', 'bring', 'broken', 'brushed', 'bst', 'btu', 'build', 'builder', 'built', 'bump', 'burner', 'burning', 'business', 'but', 'button', 'buy', 'bw', 'by', 'cable', 'cad', 'calculated', 'calculating', 'call', 'called', 'calling', 'came', 'can', 'canada', 'canadian', 'cancelled', 'cannot', 'cap', 'capability', 'capacity', 'capture', 'captured', 'capturing', 'card', 'care', 'carlos', 'carrying', 'carton', 'case', 'cast', 'category', 'caught', 'cause', 'caused', 'causing', 'cavity', 'cdn', 'cec', 'celsius', 'cem', 'center', 'centerline', 'central', 'certain', 'certificate', 'certification', 'certified', 'cf', 'cfr', 'cg', 'chamber', 'chamfer', 'chance', 'change', 'changed', 'changing', 'channel', 'chapa', 'character', 'charge', 'chaudhry', 'cheaper', 'check', 'checked', 'child', 'chile', 'chilean', 'chill', 'china', 'ci', 'cip', 'cl', 'claim', 'clamp', 'clarification', 'clarifies', 'clarify', 'clarity', 'cleanup', 'clear', 'clearance', 'clockwise', 'closed', 'closer', 'closest', 'cm', 'cmm', 'cn', 'coating', 'code', 'coil', 'colben', 'collector', 'color', 'colorado', 'colour', 'column', 'com', 'combination', 'combo', 'combustion', 'come', 'coming', 'comment', 'commercial', 'common', 'commonizing', 'communicate', 'communicated', 'communication', 'communize', 'communized', 'company', 'comparison', 'compatible', 'compete', 'competitor', 'complain', 'complains', 'complaint', 'complement', 'complementing', 'complete', 'completed', 'completion', 'compliance', 'compliant', 'comply', 'component', 'concentric', 'concept', 'concern', 'concordance', 'condensate', 'condensing', 'condition', 'conducted', 'conducting', 'config', 'c ...

# %%
def term_counts(df, stop_list = None,n_gram = (1,1)):
    
    # Count Vectorize
    cvec = CountVectorizer(stop_words = stop_list,ngram_range= n_gram)
    title_cvec = pd.DataFrame(cvec.fit_transform(lem_token_list).toarray(),
                          columns = cvec.get_feature_names())

    # See word counts
    counts = title_cvec.sum().sort_values(0, ascending=False)
    
    return counts

# %%
special_instruction_counts = pd.DataFrame(term_counts(df = df2,n_gram=(1,1),stop_list = 'english'), columns=["count"])

special_instruction_top = special_instruction_counts.head(15).sort_values(by = 'count',ascending = True)
special_instruction_top.plot(kind = 'barh',figsize=(20,12),fontsize=20)
plt.title('Frequently Occuring Words in column',size = 25)
plt.xlabel('Counts', size = 20)
plt.ylabel('Words', size = 20)
# Out:
# Text(0, 0.5, 'Words')

# %%
special_instruction_counts = pd.DataFrame(term_counts(df = lem_token_list,n_gram=(2,2),stop_list = 'english'), columns=["count"])

special_instruction_top = special_instruction_counts.head(15).sort_values(by = 'count',ascending = True)
special_instruction_top.plot(kind = 'barh',figsize=(20,12),fontsize=20)
plt.title('Frequently Occuring Bigrams in column',size = 25)
plt.xlabel('Counts', size = 20)
plt.ylabel('Words', size = 20)
# Out:
# Text(0, 0.5, 'Words')

# %%
# Print English stopwords.
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

print(stopwords.words("english"))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\muhammad.tahir.ctr\AppData\Roaming\nltk_data.
# [nltk_data]     ..
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Remove stopwords from "spam_tokens."
no_stop_words = [word for word in vocab if word not in stopwords.words('english')]

# %%
# Check it
print(no_stop_words)
# Out:
# ['_b', 'ab', 'able', 'ac', 'acceptable', 'accepted', 'access', 'accessory', 'accidentally', 'accommodate', 'accompanying', 'accomplish', 'according', 'accordinto', 'accumulation', 'accurate', 'acknowledge', 'across', 'action', 'activates', 'active', 'activity', 'actual', 'actually', 'adapt', 'adapter', 'adaptor', 'add', 'added', 'adding', 'addition', 'additional', 'address', 'adhesive', 'adjust', 'adjusted', 'adjustment', 'adoption', 'adr', 'advantage', 'advertised', 'ae', 'aesthetic', 'af', 'affect', 'affected', 'affecting', 'aftermarket', 'ag', 'agency', 'ago', 'agreed', 'ahri', 'ai', 'aid', 'aim', 'air', 'ak', 'alarm', 'alfredo', 'align', 'alignment', 'allow', 'allowable', 'allowed', 'allows', 'already', 'also', 'alternate', 'alternative', 'altitude', 'amazon', 'ambient', 'amendment', 'america', 'amount', 'analysis', 'analyze', 'ance', 'angela', 'angle', 'angular', 'annual', 'anode', 'another', 'ansi', 'antenna', 'anthony', 'anymore', 'anything', 'ao', 'ap', 'apart', 'apcom', 'app', 'appear', 'appearance', 'applicable', 'application', 'applied', 'applies', 'apply', 'approach', 'appropriate', 'approval', 'approve', 'approved', 'approx', 'arabia', 'arabian', 'area', 'arise', 'armando', 'around', 'arrow', 'art', 'artwork', 'asap', 'ask', 'asked', 'asme', 'assembled', 'assembly', 'assign', 'assigned', 'assignment', 'assist', 'associated', 'assurance', 'assure', 'assy', 'asv', 'ati', 'atmospheric', 'attached', 'attaching', 'attachment', 'attempt', 'attic', 'au', 'audit', 'auditing', 'august', 'authorization', 'auto', 'automatic', 'availability', 'available', 'average', 'avoid', 'avoided', 'awareness', 'awg', 'ax', 'az', 'aztek', 'b_obs', 'back', 'background', 'backlight', 'backwards', 'badge', 'baffle', 'bag', 'balon', 'banding', 'barcode', 'base', 'based', 'baseline', 'basic', 'battery', 'became', 'become', 'begin', 'benefit', 'better', 'bg', 'bi', 'bilingual', 'bill', 'binding', 'bird', 'bj', 'black', 'blacked', 'blank', 'blanket', 'block', 'blower', 'bm', 'board', 'boards_', 'bob', 'body', 'bolt', 'bom', 'boms', 'boot', 'bottom', 'box', 'boxed', 'boxing', 'bq', 'br', 'bracket', 'bradford', 'brand', 'branded', 'branding', 'brass', 'bravo', 'breakdown', 'bring', 'broken', 'brushed', 'bst', 'btu', 'build', 'builder', 'built', 'bump', 'burner', 'burning', 'business', 'button', 'buy', 'bw', 'cable', 'cad', 'calculated', 'calculating', 'call', 'called', 'calling', 'came', 'canada', 'canadian', 'cancelled', 'cannot', 'cap', 'capability', 'capacity', 'capture', 'captured', 'capturing', 'card', 'care', 'carlos', 'carrying', 'carton', 'case', 'cast', 'category', 'caught', 'cause', 'caused', 'causing', 'cavity', 'cdn', 'cec', 'celsius', 'cem', 'center', 'centerline', 'central', 'certain', 'certificate', 'certification', 'certified', 'cf', 'cfr', 'cg', 'chamber', 'chamfer', 'chance', 'change', 'changed', 'changing', 'channel', 'chapa', 'character', 'charge', 'chaudhry', 'cheaper', 'check', 'checked', 'child', 'chile', 'chilean', 'chill', 'china', 'ci', 'cip', 'cl', 'claim', 'clamp', 'clarification', 'clarifies', 'clarify', 'clarity', 'cleanup', 'clear', 'clearance', 'clockwise', 'closed', 'closer', 'closest', 'cm', 'cmm', 'cn', 'coating', 'code', 'coil', 'colben', 'collector', 'color', 'colorado', 'colour', 'column', 'com', 'combination', 'combo', 'combustion', 'come', 'coming', 'comment', 'commercial', 'common', 'commonizing', 'communicate', 'communicated', 'communication', 'communize', 'communized', 'company', 'comparison', 'compatible', 'compete', 'competitor', 'complain', 'complains', 'complaint', 'complement', 'complementing', 'complete', 'completed', 'completion', 'compliance', 'compliant', 'comply', 'component', 'concentric', 'concept', 'concern', 'concordance', 'condensate', 'condensing', 'condition', 'conducted', 'conducting', 'config', 'configuration', 'confirmation', 'conflict', 'confused', 'confusion', 'conjunction', 'connecting', 'connection', 'connectivity', 'connector', 'consequence', 'considered', 'considering', 'consiste ...

# %% [markdown]
# ## including stop words in below count

# %%
cvec = CountVectorizer()
# Fit our CountVectorizer on the training data and transform training data.
special_instruction_cvec = pd.DataFrame(cvec.fit_transform(df2['SPECIAL_INSTRUCTIONS']).todense(),
                          columns = cvec.get_feature_names())
print(f'Number of Unique Words: {special_instruction_cvec.shape[1]}')
special_instruction_cvec.sum()[special_instruction_cvec.sum() >= 105].sort_values(ascending = False)
# Out:
# Number of Unique Words: 2898
# the         1684
# to          1202
# and          628
# for          604
# in           482
# is           471
# be           420
# of           396
# this         285
# new          253
# on           225
# with         222
# drawing      210
# will         197
# need         193
# are          190
# drawings     180
# needed       166
# not          159
# update       151
# bom          140
# change       139
# was          139
# have         126
# end          124
# models       123
# supplier     121
# part         120
# project      118
# that         112
# by           110
# product      106
# dtype: int64

# %% [markdown]
# ## Removing stop words in below count

# %%
cvec = CountVectorizer(stop_words='english')
# Fit our CountVectorizer on the training data and transform training data.
special_instruction_cvec_stop = pd.DataFrame(cvec.fit_transform(lem_token_list).todense(),
                          columns = cvec.get_feature_names())
print(f'Number of Unique Words: {special_instruction_cvec_stop.shape[1]}')
special_instruction_cvec_stop.sum()[special_instruction_cvec_stop.sum() >= 100].sort_values(ascending = False)
# Out:
# Number of Unique Words: 1939
# drawing     390
# need        273
# new         253
# ec          230
# update      212
# change      211
# model       189
# needed      166
# bom         140
# ap          139
# wa          139
# product     137
# item        136
# label       133
# supplier    125
# end         125
# project     118
# ppap        100
# updated     100
# dtype: int64

# %% [markdown]
# ## Sentiment Analysis

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\muhammad.tahir.ctr\AppData\Roaming\nltk_data.
# [nltk_data]     ..
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Instantiate Sentiment Intensity Analyzer
sia = SentimentIntensityAnalyzer()

# %%
# Calculate sentiment of yelp_1.
sia.polarity_scores(df_notes)
# Out:
# {'neg': 0.035, 'neu': 0.888, 'pos': 0.077, 'compound': 1.0}

# %% [markdown]
# ## Description

# %%
description = df2['DESCRIPTION']
df_description = ' '.join(description.to_list())

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
word_cloud_desc = WordCloud(max_font_size=40).generate(df_description)

# %%
plt.figure(figsize=(14,8))
plt.imshow(word_cloud_desc, interpolation='bilinear')
plt.show()

# %% [markdown]
# ### word count and visual

# %% [markdown]
# # Here we have more details of description column

# %%
desc_counts = pd.DataFrame(term_counts(df = df2['DESCRIPTION'],n_gram=(1,1),stop_list = 'english'), columns=["count"])

desc_counts_words = desc_counts.head(15).sort_values(by = 'count',ascending = True)
desc_counts_words.plot(kind = 'barh',figsize=(20,12),fontsize=20)
plt.title('Frequently Occuring Words in column',size = 25)
plt.xlabel('Counts', size = 20)
plt.ylabel('Words', size = 20)
# Out:
# Text(0, 0.5, 'Words')

# %%
desc_counts = pd.DataFrame(term_counts(df = df2['DESCRIPTION'],n_gram=(2,2),stop_list = 'english'), columns=["count"])

desc_counts_words = desc_counts.head(15).sort_values(by = 'count',ascending = True)
desc_counts_words.plot(kind = 'barh',figsize=(20,12),fontsize=20)
plt.title('Frequently Occuring Words in column',size = 25)
plt.xlabel('Counts', size = 20)
plt.ylabel('Words', size = 20)
# Out:
# Text(0, 0.5, 'Words')

# %%
desc_counts = pd.DataFrame(term_counts(df = df2['DESCRIPTION'],n_gram=(3,3),stop_list = 'english'), columns=["count"])

desc_counts_words = desc_counts.head(15).sort_values(by = 'count',ascending = True)
desc_counts_words.plot(kind = 'barh',figsize=(20,12),fontsize=20)
plt.title('Frequently Occuring Words in column',size = 25)
plt.xlabel('Counts', size = 20)
plt.ylabel('Words', size = 20)
# Out:
# Text(0, 0.5, 'Words')

# %%
cvec = CountVectorizer()
# Fit our CountVectorizer on the training data and transform training data.
desc_cvec = pd.DataFrame(cvec.fit_transform(df2['DESCRIPTION']).todense(),
                          columns = cvec.get_feature_names())
print(f'Number of Unique Words: {desc_cvec.shape[1]}')
desc_cvec.sum()[desc_cvec.sum() >= 150].sort_values(ascending = False)
# Out:
# Number of Unique Words: 3534
# the          1720
# to           1178
# attached      892
# and           739
# for           688
# update        659
# drawing       571
# drawings      556
# in            508
# per           482
# create        432
# new           361
# markup        338
# of            321
# is            305
# on            300
# according     286
# bom           286
# as            282
# be            271
# markups       268
# services      266
# this          247
# part          237
# changes       235
# change        235
# make          204
# end           188
# design        180
# will          179
# with          176
# bi            166
# are           164
# items         162
# please        157
# from          157
# release       153
# dtype: int64

# %%
cvec = CountVectorizer(stop_words='english')
# Fit our CountVectorizer on the training data and transform training data.
desc_cvec = pd.DataFrame(cvec.fit_transform(df2['DESCRIPTION']).todense(),
                          columns = cvec.get_feature_names())
print(f'Number of Unique Words: {desc_cvec.shape[1]}')
desc_cvec.sum()[desc_cvec.sum() >= 100].sort_values(ascending = False)
# Out:
# Number of Unique Words: 3370
# attached       892
# update         659
# drawing        571
# drawings       556
# create         432
# new            361
# markup         338
# according      286
# bom            286
# markups        268
# services       266
# change         235
# changes        235
# make           204
# end            188
# design         180
# bi             166
# items          162
# release        153
# pss            137
# add            134
# model          130
# models         125
# level          106
# engineering    105
# revise         101
# dtype: int64

# %%
# sentiment analysis
sia.polarity_scores(df_description)
# Out:
# {'neg': 0.011, 'neu': 0.901, 'pos': 0.087, 'compound': 1.0}

# %% [markdown]
# # Title work

# %%
title = df2['TITLE']
df_title = ' '.join(title.to_list())

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
word_cloud_title = WordCloud(max_font_size=40).generate(df_title)

# %%
plt.figure(figsize=(14,8))
plt.imshow(word_cloud_title, interpolation='bilinear')
plt.show()

# %%
title_counts = pd.DataFrame(term_counts(df = df2['TITLE'],n_gram=(1,1),stop_list = 'english'), columns=["count"])

title_counts_words = title_counts.head(15).sort_values(by = 'count',ascending = True)
title_counts_words.plot(kind = 'barh',figsize=(20,12),fontsize=20)
plt.title('Frequently Occuring Words in column',size = 25)
plt.xlabel('Counts', size = 20)
plt.ylabel('Words', size = 20)
# Out:
# Text(0, 0.5, 'Words')

# %%
title_counts = pd.DataFrame(term_counts(df = df2['TITLE'],n_gram=(2,2),stop_list = 'english'), columns=["count"])

title_counts_words = title_counts.head(15).sort_values(by = 'count',ascending = True)
title_counts_words.plot(kind = 'barh',figsize=(20,12),fontsize=20)
plt.title('Frequently Occuring Words in column',size = 25)
plt.xlabel('Counts', size = 20)
plt.ylabel('Words', size = 20)
# Out:
# Text(0, 0.5, 'Words')

# %%
# sentiment analysis
sia.polarity_scores(df_title)
# Out:
# {'neg': 0.027, 'neu': 0.879, 'pos': 0.094, 'compound': 0.9999}

# %%
sia.polarity_scores('love')
# Out:
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.6369}

# %%
sia.polarity_scores('hate')
# Out:
# {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.5719}

# %%
cvec = CountVectorizer()
# Fit our CountVectorizer on the training data and transform training data.
title_cvec = pd.DataFrame(cvec.fit_transform(df2['TITLE']).todense(),
                          columns = cvec.get_feature_names())
print(f'Number of Unique Words: {title_cvec.shape[1]}')
title_cvec.sum()[title_cvec.sum() >= 50].sort_values(ascending = False)
# Out:
# Number of Unique Words: 1532
# update      228
# for         153
# to          138
# and         135
# triton      126
# drawing     113
# electric    111
# hpwh        108
# project     101
# bom          96
# xl           96
# gas          94
# dragon       92
# tankless     74
# change       74
# in           71
# create       70
# gen          70
# new          65
# eagle        60
# drawings     60
# tanks        53
# plug         52
# ready        51
# dr           51
# dtype: int64

# %%
cvec = CountVectorizer(stop_words='english')
# Fit our CountVectorizer on the training data and transform training data.
title_cvec = pd.DataFrame(cvec.fit_transform(df2['TITLE']).todense(),
                          columns = cvec.get_feature_names())
print(f'Number of Unique Words: {title_cvec.shape[1]}')
title_cvec.sum()[title_cvec.sum() >= 50].sort_values(ascending = False)
# Out:
# Number of Unique Words: 1476
# update      228
# triton      126
# drawing     113
# electric    111
# hpwh        108
# project     101
# bom          96
# xl           96
# gas          94
# dragon       92
# change       74
# tankless     74
# create       70
# gen          70
# new          65
# eagle        60
# drawings     60
# tanks        53
# plug         52
# ready        51
# dr           51
# dtype: int64

# %% [markdown]
# ## Recommendation

# %% [markdown]
# we can specify any project or task or unit and then perform analysis. this filtering method will help us to perform better sentiment analysis about any specific point.
#
# This filtering method will help us to have better word count or analysis about any specific point.
#
# what is ECN about and what exactly we need here or can separate the data ?

# %% [markdown]
# Word clouds or tag clouds are graphical representations of word frequency that give greater prominence to words that appear more frequently in a source text. The larger the word in the visual the more common the word was in the document (s)

# %% [markdown]
# ## References
#
# -- https://www.displayr.com/how-to-show-sentiment-word-clouds/
#
# -- https://www.datacamp.com/community/tutorials/wordcloud-python
#
# -- https://realpython.com/python-nltk-sentiment-analysis/
#
# -- https://www.datacamp.com/community/tutorials/simplifying-sentiment-analysis-python
#
# -- https://asperbrothers.com/blog/sentiment-analysis-in-python/
#
# -- https://algotrading101.com/learn/sentiment-analysis-python-guide/
#
# -- https://www.analyticsvidhya.com/blog/2021/06/rule-based-sentiment-analysis-in-python/
